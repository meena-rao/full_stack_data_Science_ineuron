# %%
'''1. You are given two strings s and t. String t is generated by randomly shuffling string s and then adding one more 
letter at a random position. Return the letter that was added to t.

Examples
find_the_difference("abcd", "abcde") ➞ "e"
find_the_difference("", "y") ➞ "y"
find_the_difference("ae", "aea") ➞ "a"'''

def find_the_difference(strA,strB):
    m1 = {}    
    for i in strB:
        if i in m1:
            m1[i] += 1
        else:
            m1[i] = 1
 
    for i in strA:
        m1[i] -= 1
 
    for h1 in m1:
        if m1[h1] >= 1:
            return h1

print('find_the_difference("abcd", "abcde" ) = {}'.format(find_the_difference("abcd", "abcde")))
print('find_the_difference("", "y")  = {}'.format(find_the_difference("", "y")))
print('find_the_difference("ae", "aea") = {}'.format(find_the_difference("ae", "aea")))
# Out:
# find_the_difference("abcd", "abcde" ) = e
# find_the_difference("", "y")  = y
# find_the_difference("ae", "aea") = a

# %%
'''2. Given a function that accepts unlimited arguments, check and count how many data types are in those arguments. 
Finally return the total in a list.

List order is:
[int, str, bool, list, tuple, dictionary]
Examples
count_datatypes(1, 45, "Hi", False) ➞ [2, 1, 1, 0, 0, 0]
count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1) ➞ [3, 0, 0, 1, 1, 0]
count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6]) ➞ [2, 0, 1, 2, 2, 0]'''

def count_datatypes(*args):
    li=[]
    ic,sc,bc,lc,tc,dc=0,0,0,0,0,0
    for i in args:
        if type(i) == int:
            ic+=1
        elif type(i) == str:
            sc+=1
        elif type(i) == bool:
            bc+=1             
        elif type(i) == list:
            lc+=1
        elif type(i) == tuple:
            tc+=1              
        elif type(i) == dict:
            dc+=1
        else: 
            pass
    li = [ic,sc,bc,lc,tc,dc]
    return li
    
print('count_datatypes(1, 45, "Hi", False)= {}'.format(count_datatypes(1, 45, "Hi", False)))
print('count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1)= {}'.format(count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1)))
print('count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6])=  {}'.format(count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6])))
# Out:
# count_datatypes(1, 45, "Hi", False)= [2, 1, 1, 0, 0, 0]
# count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1)= [3, 0, 0, 1, 1, 0]
# count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6])=  [2, 0, 1, 2, 2, 0]

# %%
'''3. A Fibonacci string is a precedence of the Fibonacci series. It works with any two characters of the English alphabet 
(as opposed to the numbers 0 and 1 in the Fibonacci series) as the initial items and concatenates them together as it
progresses in a similar fashion as the Fibonacci series.
Examples
fib_str(3, ["j", "h"]) ➞ "j, h, hj"
fib_str(5, ["e", "a"]) ➞ "e, a, ae, aea, aeaae"
fib_str(6, ["n", "k"]) ➞ "n, k, kn, knk, knkkn, knkknknk"'''
def fib_str(n,l):
    
    for i in range(n-2):        
        l.append(l[-1]+l[-2])
    return ', '.join(l)    

print('fib_str(3, ["j", "h"]) = {}'.format(fib_str(3, ["j", "h"])))
print('fib_str(5, ["e", "a"]) = {}'.format(fib_str(5, ["e", "a"])))
print('fib_str(6, ["n", "k"]) = {}'.format(fib_str(6, ["n", "k"])))
# Out:
# fib_str(3, ["j", "h"]) = j, h, hj
# fib_str(5, ["e", "a"]) = e, a, ae, aea, aeaae
# fib_str(6, ["n", "k"]) = n, k, kn, knk, knkkn, knkknknk

# %%
'''4.Given an integer between 0 and 26, make a variable (self.answer). That variable would be assigned to a string in this format:

"nines:your answer, threes:your answer, ones:your answer"
You need to find out how many ones, threes, and nines it would at least take for the number of each to add up to the given 
integer when multiplied by one, three or nine (depends).
Examples
ones_threes_nines(10) ➞ "nines:1, threes:0, ones:1"
ones_threes_nines(15) ➞ "nines:1, threes:2, ones:0"
ones_threes_nines(22) ➞ "nines:2, threes:1, ones:1"'''
def ones_threes_nines(n):
    c9,c3,c1=0,0,0
    while(n):
        if n>9:
            c9=c9+n//9
            n=n%9
        elif n>3:
            c3= c3+ n//3
            n=n%3
        else:
            c1+=n
            n=0
    li = [c9,c3,c1]
    li[0]= "nines:" + str(li[0])
    li[1]= "threes:" + str(li[1])  
    li[2]= "ones:" + str(li[2])
    
    return ' '.join(li)
    
print('ones_threes_nines(10) = {}'.format(ones_threes_nines(10)))
print('ones_threes_nines(15) = {}'.format(ones_threes_nines(15)))
print('ones_threes_nines(22) = {}'.format(ones_threes_nines(22)))
# Out:
# ones_threes_nines(10) = nines:1 threes:0 ones:1
# ones_threes_nines(15) = nines:1 threes:2 ones:0
# ones_threes_nines(22) = nines:2 threes:1 ones:1

# %%
'''5. The Fibonacci sequence is a classic use case for recursive functions since the value of the sequence at a given index 
is dependent on the sum of the last two values. However, the recursion tree created by solving the Fibonacci sequence 
recursively can grow quite fast. Therefore it can be important to think about the implications of running a function 
recursively. Depending on the size of n needed and the capabilities of the system in question you might want to take a 
different approach.

Write a non-recursive function that takes an integer n and returns the Fibonacci sequence's value at index n.
Examples
fib(6) ➞ 8
# 0 + 1 = 1, 1 + 1 = 2, 1 + 2 = 3, 2 + 3 = 5, 3 + 5 = 8
fib(1) ➞ 0
fib(2) ➞ 1'''
def fib(n):
    if(n==1):
        return 0
    if(n==2):
        return 1
    f1,f2 = 0,1
    for i in range(n-2):
        f3=f2+f1
        f1,f2=f2,f3
    
    return f3
print('fib(6) = {}'.format(fib(6)))
print('fib(1) = {}'.format(fib(1)))
print('fib(2) = {}'.format(fib(2)))
# Out:
# fib(6) = 5
# fib(1) = 0
# fib(2) = 1
